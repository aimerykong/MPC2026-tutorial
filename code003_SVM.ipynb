# %%
'''
Let's import useful and "standard" packages.
Not all packages will be used in the short course. It is my habit to import them
ahead of time.
'''

import numpy as np # numpy is a powerful package for numeric calculation, we rename it as "np"
import sys, os # these are system related packages
import pickle # pickle is a cute package to save and load your custom data
import shutil # for high-level file operations
import scipy, sklearn, skimage, math # these are useful packages for scientific computing, machine learning, image processing, and math calculation
import matplotlib.pyplot as plt # this is a powerful package for visualization, e.g., curves, bar charts, histograms, and various visualizations.
import cv2 # this is a powerful package for computer vision
from pathlib import Path
from PIL import Image
from sklearn.metrics import confusion_matrix

# %%
'''
Let's import the famous PyTorch package, supporting deep learning.
It is convenient to give short names for useful functions inside PyTorch
'''
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.nn.functional as F
from torch.autograd import Variable
import torchvision
from torchvision import datasets, models, transforms

# %%
# Set the global random seed for reproducibility
np.random.seed(0)

# %% [markdown]
# # load the train&val sets

# %%
filename_train = 'cls_train.pkl'
filename_val = 'cls_val.pkl'

# %%
with open(filename_train, 'rb') as file:
    trainset_info = pickle.load(file)

with open(filename_val, 'rb') as file:
    valset_info = pickle.load(file)

# %%
train_labellist = trainset_info['train_labellist']
val_labellist = valset_info['val_labellist']

numClasses = max(train_labellist)+1

# %%
train_imgs = []
val_imgs = []

for curname in trainset_info['train_imgpathlist']:
    im = skimage.io.imread(curname)
    train_imgs += [im.astype(np.float32)]

for curname in valset_info['val_imgpathlist']:
    im = skimage.io.imread(curname)
    val_imgs += [im.astype(np.float32)]

# %% [markdown]
# # Support Vector Machine (SVM)

# %%
from sklearn import svm

# %%
for i in range(len(train_imgs)):
    im = train_imgs[i]
    im = np.reshape(im,(1,-1))
    train_imgs[i] = im

for i in range(len(val_imgs)):
    im = val_imgs[i]
    im = np.reshape(im,(1,-1))
    val_imgs[i] = im

# %%
train_imgs = np.asarray(train_imgs).squeeze()
val_imgs = np.asarray(val_imgs).squeeze()

train_labellist = np.asarray(train_labellist)
val_labellist = np.asarray(val_labellist)

print(train_imgs.shape)
print(train_labellist.shape)

print(val_imgs.shape)
print(val_labellist.shape)
# Out:
# (678, 172800)
# (678,)
# (172, 172800)
# (172,)

# %%
clf = svm.SVC(kernel='linear', verbose=True, max_iter=50)
clf.fit(train_imgs, train_labellist)
# Out:
# [LibSVM].WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.639007
# nSV = 28, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.783267
# nSV = 33, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.692153
# nSV = 22, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.925213
# nSV = 30, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.159682
# nSV = 28, nBSV = 0
# ..*.*
# optimization finished, #iter = 48
# obj = -0.000000, rho = 0.244778
# nSV = 15, nBSV = 0
# .*
# optimization finished, #iter = 35
# obj = -0.000000, rho = 0.784417
# nSV = 14, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.288734
# nSV = 37, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.246996
# nSV = 42, nBSV = 0
# .*
# optimization finished, #iter = 26
# obj = -0.000000, rho = -1.297013
# nSV = 8, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.933972
# nSV = 36, nBSV = 0
# .*.*
# optimization finished, #iter = 46
# obj = -0.000000, rho = 1.096411
# nSV = 14, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.688051
# nSV = 20, nBSV = 0
# .*
# optimization finished, #iter = 28
# obj = -0.000000, rho = -0.459153
# nSV = 12, nBSV = 0
# *.WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.776176
# nSV = 17, nBSV = 0
# .*.*
# optimization finished, #iter = 39
# obj = -0.000000, rho = -0.054676
# nSV = 14, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.907429
# nSV = 30, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.081020
# nSV = 33, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.481020
# nSV = 21, nBSV = 0
# .*..*
# optimization finished, #iter = 39
# obj = -0.000000, rho = -0.245491
# nSV = 13, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.518331
# nSV = 18, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.230938
# nSV = 53, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.016364
# nSV = 45, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.331969
# nSV = 56, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.177411
# nSV = 48, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.345725
# nSV = 24, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.442739
# nSV = 32, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.454231
# nSV = 51, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.124043
# nSV = 58, nBSV = 0
# *.*
# optimization finished, #iter = 44
# obj = -0.000000, rho = -1.955879
# nSV = 16, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.070293
# nSV = 67, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.476714
# nSV = 34, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.479038
# nSV = 41, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.176317
# nSV = 27, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.708608
# nSV = 41, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.364748
# nSV = 24, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.340807, rho = -1.259303
# nSV = 25, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.195258
# nSV = 54, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.613322
# nSV = 38, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.122066
# nSV = 27, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -3.081712
# nSV = 45, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.018059
# nSV = 47, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.358035
# nSV = 56, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.394566
# nSV = 51, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.398780
# nSV = 30, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.099806
# nSV = 25, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.450720
# nSV = 71, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.451672
# nSV = 70, nBSV = 0
# *
# optimization finished, #iter = 39
# obj = -0.000000, rho = -2.778281
# nSV = 16, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.770899
# nSV = 64, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.004450
# nSV = 32, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.246541
# nSV = 35, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.031054
# nSV = 25, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.416200
# nSV = 37, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.199776
# nSV = 29, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.027808
# nSV = 53, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.422325
# nSV = 55, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.726016
# nSV = 41, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.696944
# nSV = 28, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.946708
# nSV = 41, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.612657
# nSV = 64, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.107462
# nSV = 44, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.072658
# nSV = 21, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.123677
# nSV = 30, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -2.000000, rho = 1.589622
# nSV = 50, nBSV = 1
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.277546
# nSV = 63, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.684623
# nSV = 21, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -2.000000, rho = 0.222986
# nSV = 69, nBSV = 2
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.653304
# nSV = 33, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.574655
# nSV = 37, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.026544
# nSV = 23, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.439651
# nSV = 44, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.538300
# nSV = 30, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.182652
# nSV = 60, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.883216
# nSV = 39, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.844870
# nSV = 43, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.070077
# nSV = 27, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.677149
# nSV = 49, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.099586
# nSV = 60, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.903505
# nSV = 23, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.528035
# nSV = 39, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.285662
# nSV = 52, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.366485
# nSV = 64, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.461805
# nSV = 29, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.119780
# nSV = 82, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.804105
# nSV = 43, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.307423
# nSV = 49, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.387011
# nSV = 27, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.765518
# nSV = 59, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.953163
# nSV = 37, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -2.000000, rho = 0.584492
# nSV = 71, nBSV = 2
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.103093
# nSV = 50, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.735108
# nSV = 49, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.580360
# nSV = 36, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.511066
# nSV = 58, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.199466
# nSV = 23, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.573288
# nSV = 29, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.761475
# nSV = 54, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -2.000000, rho = -1.752232
# nSV = 59, nBSV = 2
# *
# optimization finished, #iter = 33
# obj = -0.000000, rho = -6.846876
# nSV = 14, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.615502
# nSV = 67, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.205802
# nSV = 31, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.098640
# nSV = 35, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.147745
# nSV = 24, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.980619
# nSV = 33, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -4.291216
# nSV = 27, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.019582
# nSV = 57, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -2.000000, rho = 0.990097
# nSV = 41, nBSV = 2
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.603004
# nSV = 40, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.917338
# nSV = 28, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -4.588318
# nSV = 38, nBSV = 0
# .*.*
# optimization finished, #iter = 40
# obj = -0.000000, rho = -0.220842
# nSV = 15, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.407875
# nSV = 35, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.878318
# nSV = 33, nBSV = 0
# .*
# optimization finished, #iter = 23
# obj = -0.000000, rho = -2.783133
# nSV = 9, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.622279
# nSV = 28, nBSV = 0
# .*.*
# optimization finished, #iter = 41
# obj = -0.000000, rho = 1.102667
# nSV = 15, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.411807
# nSV = 22, nBSV = 0
# .*.*
# optimization finished, #iter = 28
# obj = -0.000000, rho = -1.634744
# nSV = 12, nBSV = 0
# *.WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.223066
# nSV = 20, nBSV = 0
# .*.*
# optimization finished, #iter = 40
# obj = -0.000000, rho = -1.722356
# nSV = 15, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.412506
# nSV = 27, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.297085
# nSV = 29, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.382535
# nSV = 18, nBSV = 0
# ..*
# optimization finished, #iter = 33
# obj = -0.000000, rho = -1.436910
# nSV = 11, nBSV = 0
# *.*
# optimization finished, #iter = 41
# obj = -0.000000, rho = -2.021921
# nSV = 16, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.319102
# nSV = 28, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.224134
# nSV = 35, nBSV = 0
# .*.*
# optimization finished, #iter = 33
# obj = -0.000000, rho = -3.820658
# nSV = 12, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.524094
# nSV = 43, nBSV = 0
# ..WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.658351
# nSV = 20, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.221357
# nSV = 26, nBSV = 0
# .*.*
# optimization finished, #iter = 49
# obj = -0.000000, rho = -0.292295
# nSV = 16, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.174816
# nSV = 33, nBSV = 0
# ..*
# optimization finished, #iter = 47
# obj = -0.000000, rho = -2.762391
# nSV = 17, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.018675
# nSV = 44, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.952762
# nSV = 28, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.094820
# nSV = 26, nBSV = 0
# .*.*
# optimization finished, #iter = 42
# obj = -0.000000, rho = 0.124444
# nSV = 15, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.733021
# nSV = 31, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.456843
# nSV = 77, nBSV = 0
# *
# optimization finished, #iter = 33
# obj = -0.000000, rho = -5.372859
# nSV = 11, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.945544
# nSV = 68, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.160618
# nSV = 34, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.230548
# nSV = 36, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.139326
# nSV = 25, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.882808
# nSV = 36, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -3.756889
# nSV = 27, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.752144
# nSV = 53, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.528956
# nSV = 48, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -1.116883, rho = 0.246918
# nSV = 15, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.052368
# nSV = 30, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.630428
# nSV = 37, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -4.743369
# nSV = 20, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.262307
# nSV = 81, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.988060
# nSV = 42, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.913248
# nSV = 46, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.995551
# nSV = 34, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.023814
# nSV = 44, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.506368
# nSV = 37, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.548640
# nSV = 64, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.510029
# nSV = 52, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.439995
# nSV = 55, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.264333
# nSV = 31, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.939517
# nSV = 55, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.577109
# nSV = 25, nBSV = 0
# .*.*
# optimization finished, #iter = 32
# obj = -0.000000, rho = 5.606419
# nSV = 10, nBSV = 0
# .*.WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.039632
# nSV = 15, nBSV = 0
# .*.*
# optimization finished, #iter = 28
# obj = -0.000000, rho = 3.941906
# nSV = 12, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 3.228874
# nSV = 20, nBSV = 0
# .*.*
# optimization finished, #iter = 38
# obj = -0.000000, rho = 2.890887
# nSV = 12, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.711706
# nSV = 26, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.096330
# nSV = 17, nBSV = 0
# .*
# optimization finished, #iter = 43
# obj = -0.000000, rho = 4.390199
# nSV = 16, nBSV = 0
# .*.*
# optimization finished, #iter = 23
# obj = -0.000000, rho = 5.065043
# nSV = 8, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.973464
# nSV = 19, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.053811
# nSV = 52, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.264317
# nSV = 56, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.896686
# nSV = 31, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.460120
# nSV = 53, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.895697
# nSV = 45, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 3.375188
# nSV = 79, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.242879
# nSV = 54, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.910092
# nSV = 56, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.273543
# nSV = 33, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -3.812098
# nSV = 61, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.232029
# nSV = 25, nBSV = 0
# .*.*
# optimization finished, #iter = 42
# obj = -0.000000, rho = -2.223781
# nSV = 15, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.776607
# nSV = 31, nBSV = 0
# .*.*
# optimization finished, #iter = 48
# obj = -0.000000, rho = -3.235832
# nSV = 17, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.248920
# nSV = 48, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.698615
# nSV = 34, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.185937
# nSV = 24, nBSV = 0
# ..*
# optimization finished, #iter = 41
# obj = -0.000000, rho = -1.220267
# nSV = 15, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -3.278571
# nSV = 29, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.172023
# nSV = 22, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.152601
# nSV = 37, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.829985
# nSV = 22, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.812316
# nSV = 53, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.611414
# nSV = 39, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.961077
# nSV = 31, nBSV = 0
# ..WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.249025
# nSV = 21, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -3.590120
# nSV = 38, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.978926
# nSV = 29, nBSV = 0
# .*.*
# optimization finished, #iter = 30
# obj = -0.000000, rho = -0.775975
# nSV = 14, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.020874
# nSV = 36, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.165626
# nSV = 25, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.069058
# nSV = 20, nBSV = 0
# .*.*
# optimization finished, #iter = 28
# obj = -0.000000, rho = 1.246554
# nSV = 11, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.614192
# nSV = 22, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.878436
# nSV = 26, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.352052
# nSV = 62, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.751148
# nSV = 31, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.677011
# nSV = 34, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.715781
# nSV = 28, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.257389
# nSV = 46, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.427038
# nSV = 39, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.903750
# nSV = 26, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 4.106613
# nSV = 24, nBSV = 0
# ..*
# optimization finished, #iter = 35
# obj = -0.000000, rho = 4.626753
# nSV = 12, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.508724
# nSV = 29, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.155247
# nSV = 50, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.257526
# nSV = 49, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.927697
# nSV = 33, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.877395
# nSV = 64, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.758440
# nSV = 37, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.009707
# nSV = 27, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -3.879400
# nSV = 38, nBSV = 0
# .*.WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.875088
# nSV = 18, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.732066
# nSV = 34, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -3.823462
# nSV = 22, nBSV = 0
# Total nSV = 672
# /home/gpuadmin/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=50).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# SVC(kernel='linear', max_iter=50, verbose=True)

# %%
predList = clf.predict(val_imgs)

# %%
conf = sklearn.metrics.confusion_matrix(val_labellist, predList, normalize='true')

# %%
plt.imshow(conf)

# %%
per_class_acc = np.diag(conf)
print('mean accuracy: %.3f' % per_class_acc.mean())
# Out:
# mean accuracy: 0.184

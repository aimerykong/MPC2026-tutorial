# %%
'''
Let's import useful and "standard" packages.
Not all packages will be used in the short course. It is my habit to import them
ahead of time.
'''

import numpy as np # numpy is a powerful package for numeric calculation, we rename it as "np"
import sys, os # these are system related packages
import pickle # pickle is a cute package to save and load your custom data
import shutil # for high-level file operations
import scipy, sklearn, skimage, math # these are useful packages for scientific computing, machine learning, image processing, and math calculation
import matplotlib.pyplot as plt # this is a powerful package for visualization, e.g., curves, bar charts, histograms, and various visualizations.
import cv2 # this is a powerful package for computer vision
from pathlib import Path
from PIL import Image
from sklearn.metrics import confusion_matrix

# %%
'''
Let's import the famous PyTorch package, supporting deep learning.
It is convenient to give short names for useful functions inside PyTorch
'''
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.nn.functional as F
from torch.autograd import Variable
import torchvision
from torchvision import datasets, models, transforms

# %%
# Set the global random seed for reproducibility
np.random.seed(0)

# %% [markdown]
# # load the train&val sets

# %%
filename_train = 'cls_train.pkl'
filename_val = 'cls_val.pkl'

# %%
with open(filename_train, 'rb') as file:
    trainset_info = pickle.load(file)

with open(filename_val, 'rb') as file:
    valset_info = pickle.load(file)

# %%
train_labellist = trainset_info['train_labellist']
val_labellist = valset_info['val_labellist']

numClasses = max(train_labellist)+1

# %%
train_imgs = []
val_imgs = []

for curname in trainset_info['train_imgpathlist']:
    im = skimage.io.imread(curname)
    train_imgs += [im.astype(np.float32)]

for curname in valset_info['val_imgpathlist']:
    im = skimage.io.imread(curname)
    val_imgs += [im.astype(np.float32)]

# %% [markdown]
# # Support Vector Machine (SVM)

# %%
from sklearn import svm

# %%
for i in range(len(train_imgs)):
    im = train_imgs[i]
    im = np.reshape(im,(1,-1))
    train_imgs[i] = im

for i in range(len(val_imgs)):
    im = val_imgs[i]
    im = np.reshape(im,(1,-1))
    val_imgs[i] = im

# %%
train_imgs = np.asarray(train_imgs).squeeze()
val_imgs = np.asarray(val_imgs).squeeze()

train_labellist = np.asarray(train_labellist)
val_labellist = np.asarray(val_labellist)

print(train_imgs.shape)
print(train_labellist.shape)

print(val_imgs.shape)
print(val_labellist.shape)
# Out:
# (1275, 172800)
# (1275,)
# (319, 172800)
# (319,)

# %%
clf = svm.SVC(kernel='linear', verbose=True, max_iter=50)
clf.fit(train_imgs, train_labellist)
# Out:
# [LibSVM]WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.413078
# nSV = 52, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.636250
# nSV = 55, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.675964
# nSV = 32, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.367645
# nSV = 50, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.652219
# nSV = 51, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.762291
# nSV = 30, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.843504
# nSV = 25, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.069482
# nSV = 43, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.730094
# nSV = 58, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.122995
# nSV = 21, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.332134
# nSV = 60, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.201300
# nSV = 25, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.973986
# nSV = 34, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.876553
# nSV = 24, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.585078
# nSV = 29, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -3.040265
# nSV = 24, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.133397
# nSV = 38, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.593959
# nSV = 55, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.150698
# nSV = 42, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.777410
# nSV = 31, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.577658
# nSV = 43, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.305203
# nSV = 79, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.643300
# nSV = 69, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 3.081360
# nSV = 84, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.854511
# nSV = 75, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.191409
# nSV = 49, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.093826
# nSV = 57, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.887075
# nSV = 56, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 3.269967
# nSV = 81, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.558924
# nSV = 29, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.245373
# nSV = 90, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.680133
# nSV = 51, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.405539
# nSV = 68, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.768239
# nSV = 45, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.479604
# nSV = 66, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.769373
# nSV = 48, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.907033
# nSV = 69, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.440614
# nSV = 78, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.370255
# nSV = 71, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.818998
# nSV = 56, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.247077
# nSV = 81, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.729827
# nSV = 71, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.677253
# nSV = 81, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.283397
# nSV = 76, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.342811
# nSV = 58, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.580119
# nSV = 53, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.668404
# nSV = 80, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.882531
# nSV = 90, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.881587
# nSV = 32, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.648081
# nSV = 86, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.606180
# nSV = 51, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.953731
# nSV = 61, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.231611
# nSV = 44, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.387927
# nSV = 58, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -4.289247
# nSV = 47, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.023123
# nSV = 68, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.706318
# nSV = 76, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.097899
# nSV = 78, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.106610
# nSV = 52, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.027267
# nSV = 69, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.128260
# nSV = 83, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.454009
# nSV = 70, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 3.863520
# nSV = 50, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.529793
# nSV = 61, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.533128
# nSV = 53, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.857853
# nSV = 90, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.896075
# nSV = 44, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.587413, rho = -1.578697
# nSV = 17, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.228224
# nSV = 50, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.044017
# nSV = 65, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.408987
# nSV = 49, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.896229
# nSV = 71, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.583410
# nSV = 50, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.511736
# nSV = 78, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.371283
# nSV = 66, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.437782
# nSV = 76, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.061163
# nSV = 57, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.787364
# nSV = 80, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.480767
# nSV = 83, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.183430
# nSV = 57, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.537786
# nSV = 70, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.769705
# nSV = 66, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 3.620934
# nSV = 89, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.048334
# nSV = 49, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -2.000000, rho = -2.424036
# nSV = 91, nBSV = 2
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.288414
# nSV = 56, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.005274
# nSV = 75, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.016484
# nSV = 59, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.180220
# nSV = 81, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.673940
# nSV = 56, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -2.000000, rho = -1.627631
# nSV = 79, nBSV = 2
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.393235
# nSV = 80, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.172652
# nSV = 84, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.396273
# nSV = 60, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -4.739956
# nSV = 84, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.574035
# nSV = 53, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.359520
# nSV = 50, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.553942
# nSV = 63, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.223350, rho = -1.491517
# nSV = 52, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -3.082914
# nSV = 36, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.557857
# nSV = 83, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.097973
# nSV = 49, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.180089
# nSV = 66, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -4.591426
# nSV = 44, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.950198
# nSV = 63, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -5.786868
# nSV = 39, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -4.327625
# nSV = 70, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -2.000000, rho = -1.274766
# nSV = 50, nBSV = 2
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.870947
# nSV = 70, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.422611
# nSV = 53, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.608036
# nSV = 75, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.587781
# nSV = 32, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.453149
# nSV = 51, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.795430
# nSV = 61, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -3.164351
# nSV = 21, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.615846
# nSV = 62, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.145347
# nSV = 32, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.238901
# nSV = 42, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -3.797496
# nSV = 27, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.957488
# nSV = 45, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -4.309907
# nSV = 27, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.941092
# nSV = 44, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.518343
# nSV = 52, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.253375
# nSV = 51, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.211764
# nSV = 33, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.988773
# nSV = 44, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.599261
# nSV = 37, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.799119
# nSV = 65, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -3.089388
# nSV = 28, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.923849
# nSV = 68, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.184955
# nSV = 38, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.108317
# nSV = 52, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.204988
# nSV = 33, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.151712
# nSV = 59, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.865499
# nSV = 33, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.073722
# nSV = 56, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.651988
# nSV = 48, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.274619
# nSV = 51, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.912229
# nSV = 37, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.402645
# nSV = 60, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.984836
# nSV = 76, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -3.411080
# nSV = 23, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.016704
# nSV = 71, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.583292
# nSV = 36, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -3.536403
# nSV = 41, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -5.040384
# nSV = 28, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.624544
# nSV = 43, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -5.110700
# nSV = 32, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.243659
# nSV = 47, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.487344
# nSV = 68, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.937511
# nSV = 64, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.608948
# nSV = 40, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.770502
# nSV = 50, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.610797
# nSV = 43, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.568995
# nSV = 88, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.146057
# nSV = 57, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.041544
# nSV = 73, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.954156
# nSV = 45, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.440059
# nSV = 77, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -3.872502
# nSV = 57, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.943027
# nSV = 76, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.306767
# nSV = 79, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -2.000000, rho = -0.261493
# nSV = 82, nBSV = 2
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.835896
# nSV = 58, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.448268
# nSV = 81, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.291681
# nSV = 46, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 3.423177
# nSV = 23, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.957933
# nSV = 31, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.454128
# nSV = 28, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.387046
# nSV = 41, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.134177
# nSV = 25, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.905236
# nSV = 38, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 4.180379
# nSV = 27, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.742274
# nSV = 38, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 4.615738
# nSV = 25, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 3.253547
# nSV = 42, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -1.038961, rho = -1.470343
# nSV = 19, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.692234
# nSV = 75, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.256291
# nSV = 59, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.847154
# nSV = 83, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -3.437762
# nSV = 59, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -3.687464
# nSV = 81, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.982795
# nSV = 88, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -4.358056
# nSV = 81, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.772009
# nSV = 61, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.210887
# nSV = 89, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.009784
# nSV = 44, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.964953
# nSV = 28, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.258116
# nSV = 43, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -3.864235
# nSV = 27, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.626439
# nSV = 45, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.968796
# nSV = 48, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.591602
# nSV = 42, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.728259
# nSV = 31, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.034395
# nSV = 52, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.109712
# nSV = 43, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.489666
# nSV = 57, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.865633
# nSV = 38, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 0.807573
# nSV = 65, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.577526
# nSV = 63, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.793993
# nSV = 58, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.047981
# nSV = 42, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.265654
# nSV = 65, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.894415
# nSV = 47, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.049539
# nSV = 28, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.766652
# nSV = 47, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 3.785168
# nSV = 42, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.307472
# nSV = 42, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 4.202559
# nSV = 26, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.136665
# nSV = 46, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -2.796815
# nSV = 44, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.008212
# nSV = 74, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.452454
# nSV = 56, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.595486
# nSV = 62, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.901682
# nSV = 51, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.744173
# nSV = 76, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.307627
# nSV = 41, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 5.230061
# nSV = 38, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 4.510769
# nSV = 42, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 7.400702
# nSV = 28, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 4.005660
# nSV = 46, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.461811
# nSV = 57, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.251850
# nSV = 70, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 2.189320
# nSV = 48, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = 1.010536
# nSV = 76, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.523363
# nSV = 69, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.562081
# nSV = 53, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -3.570780
# nSV = 69, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -0.433568
# nSV = 46, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.473869
# nSV = 67, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.000000, rho = -1.686907
# nSV = 57, nBSV = 0
# Total nSV = 1242
# /home/gpuadmin/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=50).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# SVC(kernel='linear', max_iter=50, verbose=True)

# %%
predList = clf.predict(val_imgs)

# %%
conf = sklearn.metrics.confusion_matrix(val_labellist, predList, normalize='true')

# %%
plt.imshow(conf)

# %%
per_class_acc = np.diag(conf)
print('mean accuracy: %.3f' % per_class_acc.mean())
# Out:
# mean accuracy: 0.154

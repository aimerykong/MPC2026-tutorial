# %%
'''
Let's import useful and "standard" packages.
Not all packages will be used in the short course. It is my habit to import them
ahead of time.
'''

import numpy as np # numpy is a powerful package for numeric calculation, we rename it as "np"
import sys, os # these are system related packages
import pickle # pickle is a cute package to save and load your custom data
import shutil # for high-level file operations
import scipy, sklearn, skimage, math # these are useful packages for scientific computing, machine learning, image processing, and math calculation
import matplotlib.pyplot as plt # this is a powerful package for visualization, e.g., curves, bar charts, histograms, and various visualizations.
import cv2 # this is a powerful package for computer vision
from pathlib import Path
from PIL import Image
from sklearn.metrics import confusion_matrix
import random

# %%
'''
Let's import the famous PyTorch package, supporting deep learning.
It is convenient to give short names for useful functions inside PyTorch
'''
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torchvision.models as models
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.nn.functional as F
from torch.autograd import Variable
import torchvision
from torchvision import datasets, models, transforms
from torchvision.transforms import v2

# %%
def seed_everything(seed=42):
    """
    Sets the random seed for reproducibility across multiple libraries and devices.
    """
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # if you are using multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False # set to False for deterministic behavior
    # torch.backends.cudnn.enabled = False # can be set to False if needed
    print(f"Random seed set to {seed}")

# Usage:
seed_everything(0)
# Out:
# Random seed set to 0

# %%
# Set the global random seed for reproducibility
np.random.seed(0) 


# set device, which gpu to use.
device ='cpu'
if torch.cuda.is_available(): 
    device='cuda:0'
print(device)
# Out:
# cuda:0

# %% [markdown]
# # load the train&val sets

# %%
filename_train = 'cls_train.pkl'
filename_val = 'cls_val.pkl'

# %%
with open(filename_train, 'rb') as file:
    trainset_info = pickle.load(file)

with open(filename_val, 'rb') as file:
    valset_info = pickle.load(file)

# %%
train_labellist = trainset_info['train_labellist']
val_labellist = valset_info['val_labellist']

numClasses = max(train_labellist)+1

# %%
train_imgs = []
val_imgs = []

for curname in trainset_info['train_imgpathlist']:
    im = skimage.io.imread(curname)
    train_imgs += [im.astype(np.float32)]

for curname in valset_info['val_imgpathlist']:
    im = skimage.io.imread(curname)
    val_imgs += [im.astype(np.float32)]

# %% [markdown]
# # load a pretrained deep neural network and extract deep features

# %%
# set device, which gpu to use.
device ='cpu'
if torch.cuda.is_available(): 
    device='cuda:0'
print(device)
# Out:
# cuda:0

# %%
torch.cuda.device_count()
torch.cuda.empty_cache()

# %%
resnet18_model = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)
feature_extractor = nn.Sequential(*list(resnet18_model.children())[:-1])

# %%
print(feature_extractor)
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (5): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (6): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (7): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (8): AdaptiveAvgPool2d(output_size=(1, 1))
# )

# %%
IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD = [0.229, 0.224, 0.225]

data_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

# %%
feature_extractor.eval()
feature_extractor.to(device);

# %%
trainFea = []
for i in range(len(train_imgs)):
    im = train_imgs[i] / 255.0
    im = data_transform(im)
    fea = feature_extractor(im.to(device).unsqueeze(0)).detach().cpu()
    trainFea += [fea]

# %%
valFea = []
for i in range(len(val_imgs)):
    im = val_imgs[i] / 255.0
    im = data_transform(im)
    fea = feature_extractor(im.to(device).unsqueeze(0)).detach().cpu()
    valFea += [fea]

# %% [markdown]
# # logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
for i in range(len(trainFea)):
    fea = trainFea[i]
    fea = fea.squeeze().detach().cpu().numpy()
    trainFea[i] = fea

for i in range(len(valFea)):
    fea = valFea[i]
    fea = fea.squeeze().detach().cpu().numpy()
    valFea[i] = fea

# %%
trainFea = np.asarray(trainFea).squeeze()
valFea = np.asarray(valFea).squeeze()

train_labellist = np.asarray(train_labellist)
val_labellist = np.asarray(val_labellist)

print(trainFea.shape)
print(train_labellist.shape)

print(valFea.shape)
print(val_labellist.shape)
# Out:
# (1275, 512)
# (1275,)
# (319, 512)
# (319,)

# %%
clf = LogisticRegression(max_iter=1000).fit(trainFea, train_labellist)

# %%
predList = clf.predict(valFea)
conf = sklearn.metrics.confusion_matrix(val_labellist, predList, normalize='true')
plt.imshow(conf)

# %%
per_class_acc = np.diag(conf)
print('mean accuracy: %.3f' % per_class_acc.mean())
# Out:
# mean accuracy: 0.282

# %% [markdown]
# # two-layer parameters

# %%
exp_dir = './exp' # experiment directory, used for reading the init model
prefix = 'vanilla'
postfix = 'v1'
weight_decay = 0.0005

project_name = prefix + '_' + postfix   # we save all the checkpoints in this directory
print(project_name)

save_dir = os.path.join(exp_dir, project_name)

log_filename = os.path.join(save_dir, 'train_%f.log' % weight_decay)
print(save_dir)

if not os.path.exists(save_dir): os.makedirs(save_dir)
# Out:
# vanilla_v1
# ./exp/vanilla_v1

# %%
class ModelArchitecture(nn.Module):
    def __init__(self, num_classes=22, pretrained=False):
        super().__init__()        
        self.fc1 = nn.Linear(512, 64)
        self.fc2 = nn.Linear(64, num_classes)
        self.dropout = nn.Dropout(0.5) 
    def forward(self, x):        
        feat = self.fc1(x)
        feat = self.dropout(feat)
        logits = self.fc2(feat)
        # logits = self.cls_head(self.dropout(feat))
        return logits

# %%
myModel = ModelArchitecture(num_classes=numClasses).to(device)
myModel.train()
# Out:
# ModelArchitecture(
#   (fc1): Linear(in_features=512, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=22, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
def initialize_weights(module):
    if isinstance(module, nn.Linear):
        # Use Kaiming uniform initialization for Linear layers (good for ReLU networks)
        nn.init.kaiming_uniform_(module.weight, nonlinearity='relu')
        if module.bias is not None:
            # Set bias to zero
            nn.init.zeros_(module.bias)
    elif isinstance(module, nn.Conv2d):
        # Use Xavier uniform initialization for Conv2d layers
        nn.init.xavier_uniform_(module.weight)
        if module.bias is not None:
            nn.init.zeros_(module.bias)

myModel.apply(initialize_weights)
# Out:
# ModelArchitecture(
#   (fc1): Linear(in_features=512, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=22, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
class pollenDataset(Dataset):
    def __init__(self, imgList, labelList):
        self.imgList = imgList
        self.labelList = labelList
        self.current_set_len = len(self.labelList)
    def __len__(self):        
        return self.current_set_len
    
    def __getitem__(self, idx):        
        cur_img = self.imgList[idx]
        cur_label = self.labelList[idx]
        return cur_img, cur_label

# %%
trainset = pollenDataset(imgList=trainFea,
                         labelList=train_labellist
                        )

valset = pollenDataset(imgList=valFea,
                       labelList=val_labellist
                      )

# %%
len(trainset), trainFea.shape, train_labellist.shape
# Out:
# (1275, (1275, 512), (1275,))

# %%
len(valset), valFea.shape, val_labellist.shape
# Out:
# (319, (319, 512), (319,))

# %%
batch_size = 64

dataloader_trainset = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=4)
dataloader_valset = DataLoader(valset, batch_size=batch_size, shuffle=False, num_workers=4)

print(len(dataloader_trainset), len(dataloader_valset))
# Out:
# 20 5

# %%
i = 0
for sample in dataloader_trainset:
    i+=1
    if i%10==0:
        print(i)
    cur_Img, cur_Label = sample
    cur_Img = cur_Img.to(device)
    cur_Label = cur_Label.to(device)
# Out:
# 10
# 20

# %%
cur_Img.shape
# Out:
# torch.Size([59, 512])

# %%
output = myModel(cur_Img)

# %%
output.shape
# Out:
# torch.Size([59, 22])

# %%
epoch_num = 100

optimizer = optim.AdamW(myModel.parameters(), lr=0.0005, betas=(0.9, 0.999), weight_decay=weight_decay)

scheduler = lr_scheduler.CosineAnnealingLR(optimizer, epoch_num, eta_min=0)

# %%
loss_fn = nn.CrossEntropyLoss()

# %%
def append_to_log(log_filename, content_string):
    fn = open(log_filename,'a')
    fn.write('{}\n'.format(content_string))    
    fn.close()

# %%
best_epoch_id = -1
best_loss = torch.inf
list_val_loss = np.zeros(epoch_num)
list_train_loss = np.zeros(epoch_num)
bestmodel_filename = os.path.join(save_dir, 'bestmodel_%f.params' % weight_decay)


fn = open(log_filename,'w')
fn.write('{}\n'.format(project_name))
fn.close()

for epoch in range(epoch_num):
    # training
    cur_string = 'epoch %d...' % (epoch)
    print(cur_string)
    append_to_log(log_filename, cur_string)
    
    myModel.train();
    cur_loss = 0
    i=0
    for sample in dataloader_trainset:
        i+=1
        if i%20==0:
            cur_string = '\t%d / %d' %(i, len(dataloader_trainset))
            print(cur_string)
            append_to_log(log_filename, cur_string)

        cur_Img, cur_Label = sample
        cur_Img = cur_Img.to(device)
        cur_Label = cur_Label.type(torch.long).view(-1).to(device)

        
        optimizer.zero_grad()

        
        logits = myModel(cur_Img) 
        loss = loss_fn(logits, cur_Label)
        cur_loss += loss.data
    
        # backward pass
        loss.backward()
        # update weights
        optimizer.step()
        
    scheduler.step()
    cur_loss = cur_loss / len(dataloader_trainset)
    list_train_loss[epoch] = cur_loss
    cur_string = '\ttrain CE: %.4f' % (cur_loss)
    print(cur_string)
    append_to_log(log_filename, cur_string)
    
    # evaluation
    cur_string = '   evaluation...'
    print(cur_string)
    append_to_log(log_filename, cur_string)
    myModel.eval();
    cur_loss = 0
    for sample in dataloader_valset:
        cur_Img, cur_Label = sample
        cur_Img = cur_Img.to(device)
        cur_Label = cur_Label.to(device)
        output = myModel(cur_Img)
        tmp = loss_fn(output, cur_Label)
        cur_loss += tmp.data
    cur_loss = cur_loss/len(dataloader_valset)
    list_val_loss[epoch] = cur_loss
    
    if cur_loss<best_loss:
        best_epoch_id = epoch
        best_loss = cur_loss
        torch.save(myModel.state_dict(), bestmodel_filename)
        
    cur_string = '\tcurrent CE: %.4f, best CE: %.4f at epoch-%d' % (cur_loss, best_loss, best_epoch_id)
    print(cur_string)
    append_to_log(log_filename, cur_string)
# Out:
# epoch 0...
# 	20 / 20
# 	train CE: 4.2665
#    evaluation...
# 	current CE: 2.9587, best CE: 2.9587 at epoch-0
# epoch 1...
# 	20 / 20
# 	train CE: 3.3938
#    evaluation...
# 	current CE: 2.7609, best CE: 2.7609 at epoch-1
# epoch 2...
# 	20 / 20
# 	train CE: 3.0538
#    evaluation...
# 	current CE: 2.6470, best CE: 2.6470 at epoch-2
# epoch 3...
# 	20 / 20
# 	train CE: 2.8124
#    evaluation...
# 	current CE: 2.5010, best CE: 2.5010 at epoch-3
# epoch 4...
# 	20 / 20
# 	train CE: 2.7073
#    evaluation...
# 	current CE: 2.4228, best CE: 2.4228 at epoch-4
# epoch 5...
# 	20 / 20
# 	train CE: 2.6003
#    evaluation...
# 	current CE: 2.3521, best CE: 2.3521 at epoch-5
# epoch 6...
# 	20 / 20
# 	train CE: 2.4896
#    evaluation...
# 	current CE: 2.3021, best CE: 2.3021 at epoch-6
# epoch 7...
# 	20 / 20
# 	train CE: 2.3960
#    evaluation...
# 	current CE: 2.2696, best CE: 2.2696 at epoch-7
# epoch 8...
# 	20 / 20
# 	train CE: 2.3497
#    evaluation...
# 	current CE: 2.2210, best CE: 2.2210 at epoch-8
# epoch 9...
# 	20 / 20
# 	train CE: 2.2631
#    evaluation...
# 	current CE: 2.2018, best CE: 2.2018 at epoch-9
# epoch 10...
# 	20 / 20
# 	train CE: 2.2298
#    evaluation...
# 	current CE: 2.1654, best CE: 2.1654 at epoch-10
# epoch 11...
# 	20 / 20
# 	train CE: 2.1673
#    evaluation...
# 	current CE: 2.1404, best CE: 2.1404 at epoch-11
# epoch 12...
# 	20 / 20
# 	train CE: 2.0912
#    evaluation...
# 	current CE: 2.1342, best CE: 2.1342 at epoch-12
# epoch 13...
# 	20 / 20
# 	train CE: 2.0267
#    evaluation...
# 	current CE: 2.1014, best CE: 2.1014 at epoch-13
# epoch 14...
# 	20 / 20
# 	train CE: 1.9910
#    evaluation...
# 	current CE: 2.0777, best CE: 2.0777 at epoch-14
# epoch 15...
# 	20 / 20
# 	train CE: 1.9658
#    evaluation...
# 	current CE: 2.0853, best CE: 2.0777 at epoch-14
# epoch 16...
# 	20 / 20
# 	train CE: 1.9260
#    evaluation...
# 	current CE: 2.0646, best CE: 2.0646 at epoch-16
# epoch 17...
# 	20 / 20
# 	train CE: 1.8638
#    evaluation...
# 	current CE: 2.0454, best CE: 2.0454 at epoch-17
# epoch 18...
# 	20 / 20
# 	train CE: 1.8886
#    evaluation...
# 	current CE: 2.0520, best CE: 2.0454 at epoch-17
# epoch 19...
# 	20 / 20
# 	train CE: 1.8325
#    evaluation...
# 	current CE: 2.0425, best CE: 2.0425 at epoch-19
# epoch 20...
# 	20 / 20
# 	train CE: 1.8267
#    evaluation...
# 	current CE: 2.0276, best CE: 2.0276 at epoch-20
# epoch 21...
# 	20 / 20
# 	train CE: 1.7790
#    evaluation...
# 	current CE: 2.0444, best CE: 2.0276 at epoch-20
# epoch 22...
# 	20 / 20
# 	train CE: 1.7358
#    evaluation...
# 	current CE: 2.0195, best CE: 2.0195 at epoch-22
# epoch 23...
# 	20 / 20
# 	train CE: 1.7267
#    evaluation...
# 	current CE: 2.0148, best CE: 2.0148 at epoch-23
# epoch 24...
# 	20 / 20
# 	train CE: 1.6753
#    evaluation...
# 	current CE: 2.0045, best CE: 2.0045 at epoch-24
# epoch 25...
# 	20 / 20
# 	train CE: 1.6879
#    evaluation...
# 	current CE: 2.0088, best CE: 2.0045 at epoch-24
# epoch 26...
# 	20 / 20
# 	train CE: 1.6260
#    evaluation...
# 	current CE: 2.0084, best CE: 2.0045 at epoch-24
# epoch 27...
# 	20 / 20
# 	train CE: 1.6517
#    evaluation...
# 	current CE: 2.0029, best CE: 2.0029 at epoch-27
# epoch 28...
# 	20 / 20
# 	train CE: 1.5900
#    evaluation...
# 	current CE: 1.9952, best CE: 1.9952 at epoch-28
# epoch 29...
# 	20 / 20
# 	train CE: 1.5982
#    evaluation...
# 	current CE: 1.9920, best CE: 1.9920 at epoch-29
# epoch 30...
# 	20 / 20
# 	train CE: 1.5923
#    evaluation...
# 	current CE: 1.9896, best CE: 1.9896 at epoch-30
# epoch 31...
# 	20 / 20
# 	train CE: 1.5159
#    evaluation...
# 	current CE: 1.9970, best CE: 1.9896 at epoch-30
# epoch 32...
# 	20 / 20
# 	train CE: 1.5477
#    evaluation...
# 	current CE: 1.9815, best CE: 1.9815 at epoch-32
# epoch 33...
# 	20 / 20
# 	train CE: 1.5163
#    evaluation...
# 	current CE: 1.9868, best CE: 1.9815 at epoch-32
# epoch 34...
# 	20 / 20
# 	train CE: 1.4922
#    evaluation...
# 	current CE: 1.9694, best CE: 1.9694 at epoch-34
# epoch 35...
# 	20 / 20
# 	train CE: 1.4600
#    evaluation...
# 	current CE: 1.9712, best CE: 1.9694 at epoch-34
# epoch 36...
# 	20 / 20
# 	train CE: 1.4853
#    evaluation...
# 	current CE: 1.9757, best CE: 1.9694 at epoch-34
# epoch 37...
# 	20 / 20
# 	train CE: 1.4630
#    evaluation...
# 	current CE: 1.9905, best CE: 1.9694 at epoch-34
# epoch 38...
# 	20 / 20
# 	train CE: 1.4463
#    evaluation...
# 	current CE: 1.9765, best CE: 1.9694 at epoch-34
# epoch 39...
# 	20 / 20
# 	train CE: 1.4612
#    evaluation...
# 	current CE: 1.9738, best CE: 1.9694 at epoch-34
# epoch 40...
# 	20 / 20
# 	train CE: 1.4699
#    evaluation...
# 	current CE: 1.9714, best CE: 1.9694 at epoch-34
# epoch 41...
# 	20 / 20
# 	train CE: 1.4188
#    evaluation...
# 	current CE: 1.9855, best CE: 1.9694 at epoch-34
# epoch 42...
# 	20 / 20
# 	train CE: 1.4026
#    evaluation...
# 	current CE: 1.9680, best CE: 1.9680 at epoch-42
# epoch 43...
# 	20 / 20
# 	train CE: 1.3837
#    evaluation...
# 	current CE: 1.9840, best CE: 1.9680 at epoch-42
# epoch 44...
# 	20 / 20
# 	train CE: 1.3833
#    evaluation...
# 	current CE: 1.9684, best CE: 1.9680 at epoch-42
# epoch 45...
# 	20 / 20
# 	train CE: 1.3711
#    evaluation...
# 	current CE: 1.9732, best CE: 1.9680 at epoch-42
# epoch 46...
# 	20 / 20
# 	train CE: 1.3837
#    evaluation...
# 	current CE: 1.9614, best CE: 1.9614 at epoch-46
# epoch 47...
# 	20 / 20
# 	train CE: 1.3296
#    evaluation...
# 	current CE: 1.9730, best CE: 1.9614 at epoch-46
# epoch 48...
# 	20 / 20
# 	train CE: 1.3057
#    evaluation...
# 	current CE: 1.9612, best CE: 1.9612 at epoch-48
# epoch 49...
# 	20 / 20
# 	train CE: 1.3327
#    evaluation...
# 	current CE: 1.9673, best CE: 1.9612 at epoch-48
# epoch 50...
# 	20 / 20
# 	train CE: 1.3498
#    evaluation...
# 	current CE: 1.9750, best CE: 1.9612 at epoch-48
# epoch 51...
# 	20 / 20
# 	train CE: 1.3248
#    evaluation...
# 	current CE: 1.9677, best CE: 1.9612 at epoch-48
# epoch 52...
# 	20 / 20
# 	train CE: 1.2761
#    evaluation...
# 	current CE: 1.9765, best CE: 1.9612 at epoch-48
# epoch 53...
# 	20 / 20
# 	train CE: 1.2859
#    evaluation...
# 	current CE: 1.9683, best CE: 1.9612 at epoch-48
# epoch 54...
# 	20 / 20
# 	train CE: 1.2962
#    evaluation...
# 	current CE: 1.9682, best CE: 1.9612 at epoch-48
# epoch 55...
# 	20 / 20
# 	train CE: 1.2658
#    evaluation...
# 	current CE: 1.9700, best CE: 1.9612 at epoch-48
# epoch 56...
# 	20 / 20
# 	train CE: 1.2736
#    evaluation...
# 	current CE: 1.9708, best CE: 1.9612 at epoch-48
# epoch 57...
# 	20 / 20
# 	train CE: 1.2755
#    evaluation...
# 	current CE: 1.9741, best CE: 1.9612 at epoch-48
# epoch 58...
# 	20 / 20
# 	train CE: 1.2890
#    evaluation...
# 	current CE: 1.9664, best CE: 1.9612 at epoch-48
# epoch 59...
# 	20 / 20
# 	train CE: 1.2577
#    evaluation...
# 	current CE: 1.9713, best CE: 1.9612 at epoch-48
# epoch 60...
# 	20 / 20
# 	train CE: 1.2436
#    evaluation...
# 	current CE: 1.9673, best CE: 1.9612 at epoch-48
# epoch 61...
# 	20 / 20
# 	train CE: 1.2576
#    evaluation...
# 	current CE: 1.9751, best CE: 1.9612 at epoch-48
# epoch 62...
# 	20 / 20
# 	train CE: 1.2506
#    evaluation...
# 	current CE: 1.9709, best CE: 1.9612 at epoch-48
# epoch 63...
# 	20 / 20
# 	train CE: 1.2480
#    evaluation...
# 	current CE: 1.9753, best CE: 1.9612 at epoch-48
# epoch 64...
# 	20 / 20
# 	train CE: 1.2192
#    evaluation...
# 	current CE: 1.9724, best CE: 1.9612 at epoch-48
# epoch 65...
# 	20 / 20
# 	train CE: 1.2040
#    evaluation...
# 	current CE: 1.9719, best CE: 1.9612 at epoch-48
# epoch 66...
# 	20 / 20
# 	train CE: 1.2389
#    evaluation...
# 	current CE: 1.9812, best CE: 1.9612 at epoch-48
# epoch 67...
# 	20 / 20
# 	train CE: 1.2359
#    evaluation...
# 	current CE: 1.9702, best CE: 1.9612 at epoch-48
# epoch 68...
# 	20 / 20
# 	train CE: 1.1878
#    evaluation...
# 	current CE: 1.9735, best CE: 1.9612 at epoch-48
# epoch 69...
# 	20 / 20
# 	train CE: 1.1867
#    evaluation...
# 	current CE: 1.9731, best CE: 1.9612 at epoch-48
# epoch 70...
# 	20 / 20
# 	train CE: 1.1987
#    evaluation...
# 	current CE: 1.9721, best CE: 1.9612 at epoch-48
# epoch 71...
# 	20 / 20
# 	train CE: 1.2168
#    evaluation...
# 	current CE: 1.9745, best CE: 1.9612 at epoch-48
# epoch 72...
# 	20 / 20
# 	train CE: 1.2167
#    evaluation...
# 	current CE: 1.9731, best CE: 1.9612 at epoch-48
# epoch 73...
# 	20 / 20
# 	train CE: 1.1820
#    evaluation...
# 	current CE: 1.9759, best CE: 1.9612 at epoch-48
# epoch 74...
# 	20 / 20
# 	train CE: 1.2039
#    evaluation...
# 	current CE: 1.9753, best CE: 1.9612 at epoch-48
# epoch 75...
# 	20 / 20
# 	train CE: 1.1858
#    evaluation...
# 	current CE: 1.9763, best CE: 1.9612 at epoch-48
# epoch 76...
# 	20 / 20
# 	train CE: 1.2035
#    evaluation...
# 	current CE: 1.9742, best CE: 1.9612 at epoch-48
# epoch 77...
# 	20 / 20
# 	train CE: 1.1816
#    evaluation...
# 	current CE: 1.9753, best CE: 1.9612 at epoch-48
# epoch 78...
# 	20 / 20
# 	train CE: 1.2118
#    evaluation...
# 	current CE: 1.9755, best CE: 1.9612 at epoch-48
# epoch 79...
# 	20 / 20
# 	train CE: 1.2017
#    evaluation...
# 	current CE: 1.9770, best CE: 1.9612 at epoch-48
# epoch 80...
# 	20 / 20
# 	train CE: 1.1772
#    evaluation...
# 	current CE: 1.9760, best CE: 1.9612 at epoch-48
# epoch 81...
# 	20 / 20
# 	train CE: 1.1845
#    evaluation...
# 	current CE: 1.9744, best CE: 1.9612 at epoch-48
# epoch 82...
# 	20 / 20
# 	train CE: 1.1698
#    evaluation...
# 	current CE: 1.9736, best CE: 1.9612 at epoch-48
# epoch 83...
# 	20 / 20
# 	train CE: 1.1864
#    evaluation...
# 	current CE: 1.9741, best CE: 1.9612 at epoch-48
# epoch 84...
# 	20 / 20
# 	train CE: 1.1881
#    evaluation...
# 	current CE: 1.9750, best CE: 1.9612 at epoch-48
# epoch 85...
# 	20 / 20
# 	train CE: 1.1692
#    evaluation...
# 	current CE: 1.9740, best CE: 1.9612 at epoch-48
# epoch 86...
# 	20 / 20
# 	train CE: 1.1592
#    evaluation...
# 	current CE: 1.9756, best CE: 1.9612 at epoch-48
# epoch 87...
# 	20 / 20
# 	train CE: 1.1651
#    evaluation...
# 	current CE: 1.9758, best CE: 1.9612 at epoch-48
# epoch 88...
# 	20 / 20
# 	train CE: 1.1823
#    evaluation...
# 	current CE: 1.9747, best CE: 1.9612 at epoch-48
# epoch 89...
# 	20 / 20
# 	train CE: 1.1762
#    evaluation...
# 	current CE: 1.9751, best CE: 1.9612 at epoch-48
# epoch 90...
# 	20 / 20
# 	train CE: 1.1680
#    evaluation...
# 	current CE: 1.9757, best CE: 1.9612 at epoch-48
# epoch 91...
# 	20 / 20
# 	train CE: 1.1565
#    evaluation...
# 	current CE: 1.9759, best CE: 1.9612 at epoch-48
# epoch 92...
# 	20 / 20
# 	train CE: 1.1808
#    evaluation...
# 	current CE: 1.9756, best CE: 1.9612 at epoch-48
# epoch 93...
# 	20 / 20
# 	train CE: 1.1846
#    evaluation...
# 	current CE: 1.9750, best CE: 1.9612 at epoch-48
# epoch 94...
# 	20 / 20
# 	train CE: 1.1899
#    evaluation...
# 	current CE: 1.9751, best CE: 1.9612 at epoch-48
# epoch 95...
# 	20 / 20
# 	train CE: 1.1684
#    evaluation...
# 	current CE: 1.9751, best CE: 1.9612 at epoch-48
# epoch 96...
# 	20 / 20
# 	train CE: 1.1728
#    evaluation...
# 	current CE: 1.9752, best CE: 1.9612 at epoch-48
# epoch 97...
# 	20 / 20
# 	train CE: 1.2067
#    evaluation...
# 	current CE: 1.9752, best CE: 1.9612 at epoch-48
# epoch 98...
# 	20 / 20
# 	train CE: 1.1987
#    evaluation...
# 	current CE: 1.9752, best CE: 1.9612 at epoch-48
# epoch 99...
# 	20 / 20
# 	train CE: 1.1655
#    evaluation...
# 	current CE: 1.9752, best CE: 1.9612 at epoch-48

# %%
plt.plot(list_train_loss, label='train loss')
plt.plot(list_val_loss, label='val loss')
plt.legend()

# %% [markdown]
# # Use the last checkpoint

# %%
myModel.eval();
predList = []
grndList = []
for sample in dataloader_valset:
    cur_Img, cur_Label = sample
    cur_Img = cur_Img.to(device)
    cur_Label = cur_Label.to(device)
    logits = myModel(cur_Img).detach()
    output = F.softmax(logits, dim=0)
    output = output.cpu().numpy()
    output = np.argmax(output, 1)
    predList = np.concatenate((predList, output))
    grndList = np.concatenate((grndList, cur_Label.cpu()))

# %%
conf = sklearn.metrics.confusion_matrix(grndList, predList, normalize='true')

plt.imshow(conf)

# %%
per_class_acc = np.diag(conf)
print('mean accuracy: %.3f' % per_class_acc.mean())
# Out:
# mean accuracy: 0.166

# %% [markdown]
# # Use the selected checkpoint

# %%
bestmodel_filename
# Out:
# './exp/vanilla_v1/bestmodel_0.000500.params'

# %%
myModel = ModelArchitecture(num_classes=numClasses).to(device)
myModel.load_state_dict(torch.load(bestmodel_filename))
# Out:
# <All keys matched successfully>

# %%
# A = torch.load(bestmodel_filename)

# %%
myModel.eval();
predList = []
grndList = []
for sample in dataloader_valset:
    cur_Img, cur_Label = sample
    cur_Img = cur_Img.to(device)
    cur_Label = cur_Label.to(device)
    logits = myModel(cur_Img).detach()
    output = F.softmax(logits, dim=0)
    output = output.cpu().numpy()
    output = np.argmax(output, 1)
    predList = np.concatenate((predList, output))
    grndList = np.concatenate((grndList, cur_Label.cpu()))

# %%
conf = sklearn.metrics.confusion_matrix(val_labellist, predList, normalize='true')

plt.imshow(conf)

# %%
per_class_acc = np.diag(conf)
print('mean accuracy: %.3f' % per_class_acc.mean())
# Out:
# mean accuracy: 0.182

# %%
'''
Let's import useful and "standard" packages.
Not all packages will be used in the short course. It is my habit to import them
ahead of time.
'''

import numpy as np # numpy is a powerful package for numeric calculation, we rename it as "np"
import sys, os # these are system related packages
import pickle # pickle is a cute package to save and load your custom data
import shutil # for high-level file operations
import scipy, sklearn, skimage, math # these are useful packages for scientific computing, machine learning, image processing, and math calculation
import matplotlib.pyplot as plt # this is a powerful package for visualization, e.g., curves, bar charts, histograms, and various visualizations.
import cv2 # this is a powerful package for computer vision
from pathlib import Path
from PIL import Image
from sklearn.metrics import confusion_matrix

# %%
'''
Let's import the famous PyTorch package, supporting deep learning.
It is convenient to give short names for useful functions inside PyTorch
'''
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torchvision.models as models
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.nn.functional as F
from torch.autograd import Variable
import torchvision
from torchvision import datasets, models, transforms

# %%
# Set the global random seed for reproducibility
np.random.seed(0)

# %% [markdown]
# # load the train&val sets

# %%
filename_train = 'cls_train.pkl'
filename_val = 'cls_val.pkl'

# %%
with open(filename_train, 'rb') as file:
    trainset_info = pickle.load(file)

with open(filename_val, 'rb') as file:
    valset_info = pickle.load(file)

# %%
train_labellist = trainset_info['train_labellist']
val_labellist = valset_info['val_labellist']

numClasses = max(train_labellist)+1

# %%
train_imgs = []
val_imgs = []

for curname in trainset_info['train_imgpathlist']:
    im = skimage.io.imread(curname)
    train_imgs += [im.astype(np.float32)]

for curname in valset_info['val_imgpathlist']:
    im = skimage.io.imread(curname)
    val_imgs += [im.astype(np.float32)]

# %% [markdown]
# # load a pretrained deep neural network and extract deep features

# %%
# set device, which gpu to use.
device ='cpu'
if torch.cuda.is_available(): 
    device='cuda:0'
print(device)
# Out:
# cuda:0

# %%
torch.cuda.device_count()
torch.cuda.empty_cache()

# %%
resnet18_model = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)
feature_extractor = nn.Sequential(*list(resnet18_model.children())[:-1])

# %%
print(feature_extractor)
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (5): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (6): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (7): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (8): AdaptiveAvgPool2d(output_size=(1, 1))
# )

# %%
feature_extractor.eval()
feature_extractor.to(device);

# %%
IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD = [0.229, 0.224, 0.225]

data_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

# %%
trainFea = []
for i in range(len(train_imgs)):
    im = train_imgs[i] / 255.0
    im = data_transform(im)
    fea = feature_extractor(im.to(device).unsqueeze(0))
    trainFea += [fea]

# %%
valFea = []
for i in range(len(val_imgs)):
    im = val_imgs[i] / 255.0
    im = data_transform(im)
    fea = feature_extractor(im.to(device).unsqueeze(0))
    valFea += [fea]

# %% [markdown]
# # Nearest Neighbor Classifier over the deep features

# %%
def NearestNeighbor(Database, test_img):
    distanceList = []
    for i in range(len(Database)):
        curExample = Database[i]
        tmp = (curExample - test_img)**2
        distanceList += [tmp.sum().detach().cpu().numpy()]
    return distanceList

# %%
predList = []
for i in range(len(valFea)):
    cur_fea = valFea[i]
    distanceList = NearestNeighbor(trainFea, cur_fea)
    targetIdx = np.argmin(distanceList)
    predLabel = train_labellist[targetIdx]
    predList += [predLabel]

    if i%10==0:
        print('%d/%d...' %(i, len(val_imgs)))
# Out:
# 0/172...
# 10/172...
# 20/172...
# 30/172...
# 40/172...
# 50/172...
# 60/172...
# 70/172...
# 80/172...
# 90/172...
# 100/172...
# 110/172...
# 120/172...
# 130/172...
# 140/172...
# 150/172...
# 160/172...
# 170/172...

# %%
conf = sklearn.metrics.confusion_matrix(val_labellist, predList, normalize='true')

plt.imshow(conf)

# %%
per_class_acc = np.diag(conf)
print('mean accuracy: %.3f' % per_class_acc.mean())
# Out:
# mean accuracy: 0.242

# %% [markdown]
# # Support Vector Machine (SVM)

# %%
from sklearn import svm

# %%
for i in range(len(trainFea)):
    fea = trainFea[i]
    fea = fea.squeeze().detach().cpu().numpy()
    trainFea[i] = fea

for i in range(len(valFea)):
    fea = valFea[i]
    fea = fea.squeeze().detach().cpu().numpy()
    valFea[i] = fea

# %%
trainFea = np.asarray(trainFea).squeeze()
valFea = np.asarray(valFea).squeeze()

train_labellist = np.asarray(train_labellist)
val_labellist = np.asarray(val_labellist)

print(trainFea.shape)
print(train_labellist.shape)

print(valFea.shape)
print(val_labellist.shape)
# Out:
# (678, 512)
# (678,)
# (172, 512)
# (172,)

# %%
clf = svm.SVC(kernel='linear', verbose=True, max_iter=50)
clf.fit(trainFea, train_labellist)
# Out:
# [LibSVM]*.WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.076898, rho = 0.614583
# nSV = 23, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.079380, rho = 0.827672
# nSV = 29, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.050919, rho = 1.190961
# nSV = 21, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.065000, rho = 1.420867
# nSV = 25, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.081722, rho = 1.546386
# nSV = 28, nBSV = 0
# .*.*
# optimization finished, #iter = 36
# obj = -0.053284, rho = 0.262300
# nSV = 14, nBSV = 0
# .*
# optimization finished, #iter = 33
# obj = -0.042333, rho = 0.048980
# nSV = 14, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.086297, rho = 0.081967
# nSV = 34, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.100870, rho = 1.168841
# nSV = 33, nBSV = 0
# .*
# optimization finished, #iter = 26
# obj = -0.027559, rho = 0.738705
# nSV = 10, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.113488, rho = 1.546162
# nSV = 32, nBSV = 0
# .*.*
# optimization finished, #iter = 45
# obj = -0.052829, rho = 1.038013
# nSV = 16, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.055038, rho = 1.308691
# nSV = 19, nBSV = 0
# .*.*
# optimization finished, #iter = 32
# obj = -0.037228, rho = 0.720856
# nSV = 14, nBSV = 0
# *.WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.037412, rho = 1.246091
# nSV = 22, nBSV = 0
# .*.*
# optimization finished, #iter = 32
# obj = -0.043502, rho = 0.808763
# nSV = 14, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.063550, rho = 1.530594
# nSV = 25, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.069477, rho = 1.155198
# nSV = 22, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.052261, rho = 0.245182
# nSV = 20, nBSV = 0
# .*
# optimization finished, #iter = 25
# obj = -0.033348, rho = 0.757839
# nSV = 10, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.041270, rho = 1.205185
# nSV = 20, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.194991, rho = -0.612772
# nSV = 43, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.267727, rho = 0.744280
# nSV = 40, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.409606, rho = 0.082600
# nSV = 48, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.317371, rho = 0.195111
# nSV = 39, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.093068, rho = -1.620029
# nSV = 24, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.195296, rho = -0.251872
# nSV = 25, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.239872, rho = 0.249650
# nSV = 49, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.188614, rho = -0.010187
# nSV = 46, nBSV = 0
# *.*
# optimization finished, #iter = 47
# obj = -0.076677, rho = 0.237575
# nSV = 20, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.300759, rho = 0.397864
# nSV = 51, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.236532, rho = -0.395261
# nSV = 33, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.209887, rho = 0.649555
# nSV = 35, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.111245, rho = 0.003662
# nSV = 24, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.239142, rho = 1.635104
# nSV = 38, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.080223, rho = -0.132116
# nSV = 20, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -2.297828, rho = 0.184638
# nSV = 52, nBSV = 2
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.248495, rho = -0.218591
# nSV = 45, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.237192, rho = -0.899907
# nSV = 38, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.125597, rho = 0.468601
# nSV = 22, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.208994, rho = 0.257652
# nSV = 38, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.356278, rho = 0.989037
# nSV = 46, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.306432, rho = 0.999560
# nSV = 53, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.240834, rho = 1.227743
# nSV = 49, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.149189, rho = -1.621558
# nSV = 31, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.074493, rho = 0.375208
# nSV = 24, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.631806, rho = 0.969983
# nSV = 63, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.413386, rho = 0.896686
# nSV = 60, nBSV = 0
# *.WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.059260, rho = 0.892393
# nSV = 19, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.593529, rho = 0.383779
# nSV = 61, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.102128, rho = 0.595337
# nSV = 31, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.164646, rho = 1.700309
# nSV = 34, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.116547, rho = 0.538960
# nSV = 27, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.108998, rho = 1.425791
# nSV = 33, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.092355, rho = 0.984302
# nSV = 23, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.317525, rho = 1.883487
# nSV = 49, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.149456, rho = 0.451579
# nSV = 39, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.193207, rho = 0.153044
# nSV = 31, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.060722, rho = 0.751394
# nSV = 22, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.088748, rho = 1.607395
# nSV = 35, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.458539, rho = -0.496221
# nSV = 55, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.266373, rho = -0.102287
# nSV = 42, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.094783, rho = -1.314163
# nSV = 25, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.136103, rho = -0.036965
# nSV = 25, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -2.338711, rho = -1.521874
# nSV = 47, nBSV = 1
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.333925, rho = -0.807374
# nSV = 54, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.081999, rho = 0.247949
# nSV = 19, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -2.728124, rho = -0.850692
# nSV = 65, nBSV = 2
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.147527, rho = -0.824684
# nSV = 28, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.197257, rho = -0.446905
# nSV = 31, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.105305, rho = -0.469896
# nSV = 29, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.232518, rho = 0.939490
# nSV = 43, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.095794, rho = -0.543570
# nSV = 25, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.573306, rho = -1.924404
# nSV = 57, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.096112, rho = -0.110455
# nSV = 34, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.387368, rho = -1.452115
# nSV = 36, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.110284, rho = 0.461175
# nSV = 20, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.238003, rho = -0.248896
# nSV = 33, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.294899, rho = 0.945576
# nSV = 49, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.102077, rho = -1.400844
# nSV = 30, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.205174, rho = 0.094725
# nSV = 31, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.256938, rho = 0.622670
# nSV = 46, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.399903, rho = -1.667066
# nSV = 53, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.227216, rho = 0.422401
# nSV = 28, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.779393, rho = 0.660565
# nSV = 72, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.232970, rho = -0.083250
# nSV = 37, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.329187, rho = 0.077007
# nSV = 46, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.152377, rho = -0.275959
# nSV = 34, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.612375, rho = 2.764505
# nSV = 57, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.105405, rho = -0.510029
# nSV = 25, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -2.744049, rho = 1.541540
# nSV = 69, nBSV = 2
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.295813, rho = 0.173213
# nSV = 50, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.332757, rho = -0.792393
# nSV = 44, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.174898, rho = 0.360749
# nSV = 31, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.379168, rho = 0.708749
# nSV = 50, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.090482, rho = -1.941151
# nSV = 28, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.112004, rho = -0.662216
# nSV = 23, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.263264, rho = -0.776043
# nSV = 49, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -2.331953, rho = -1.203368
# nSV = 51, nBSV = 2
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.069299, rho = 0.112339
# nSV = 19, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.518637, rho = -0.227363
# nSV = 60, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.172708, rho = -0.316797
# nSV = 26, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.164781, rho = 0.098406
# nSV = 36, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.125910, rho = -0.250894
# nSV = 28, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.229827, rho = 1.110789
# nSV = 38, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.126661, rho = -1.284640
# nSV = 24, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.271599, rho = 0.192363
# nSV = 51, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -2.165281, rho = -0.427498
# nSV = 39, nBSV = 1
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.213580, rho = -1.514551
# nSV = 35, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.087163, rho = 0.274136
# nSV = 20, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.161650, rho = 0.465319
# nSV = 29, nBSV = 0
# .*
# optimization finished, #iter = 33
# obj = -0.041303, rho = 0.507505
# nSV = 14, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.172752, rho = 0.548027
# nSV = 38, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.118550, rho = 0.977630
# nSV = 33, nBSV = 0
# .*.*
# optimization finished, #iter = 27
# obj = -0.031085, rho = 0.739493
# nSV = 11, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.123484, rho = 1.325083
# nSV = 38, nBSV = 0
# .*.*
# optimization finished, #iter = 46
# obj = -0.071847, rho = 0.818677
# nSV = 16, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.060487, rho = 1.222446
# nSV = 20, nBSV = 0
# .*
# optimization finished, #iter = 27
# obj = -0.047183, rho = 0.775289
# nSV = 13, nBSV = 0
# *.WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.055715, rho = 1.647232
# nSV = 22, nBSV = 0
# .*.*
# optimization finished, #iter = 30
# obj = -0.040254, rho = 0.818525
# nSV = 14, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.094870, rho = 1.737631
# nSV = 31, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.072739, rho = 0.926689
# nSV = 28, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.078741, rho = 0.572098
# nSV = 18, nBSV = 0
# .*.*
# optimization finished, #iter = 28
# obj = -0.043521, rho = 1.058667
# nSV = 12, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.058141, rho = 1.429887
# nSV = 23, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.110136, rho = -0.335303
# nSV = 29, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.103324, rho = -0.042739
# nSV = 27, nBSV = 0
# .*.*
# optimization finished, #iter = 33
# obj = -0.048330, rho = 0.848283
# nSV = 13, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.152699, rho = 1.348361
# nSV = 34, nBSV = 0
# .*.WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.159895, rho = 0.486543
# nSV = 19, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.144390, rho = 0.499606
# nSV = 22, nBSV = 0
# .*.*
# optimization finished, #iter = 41
# obj = -0.064107, rho = 0.114226
# nSV = 15, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.159014, rho = 1.320739
# nSV = 28, nBSV = 0
# .*.*
# optimization finished, #iter = 39
# obj = -0.046911, rho = 0.161455
# nSV = 14, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.185252, rho = 0.073568
# nSV = 35, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.089992, rho = 0.522288
# nSV = 25, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.161164, rho = -0.586264
# nSV = 26, nBSV = 0
# .*.*
# optimization finished, #iter = 34
# obj = -0.085225, rho = 1.174065
# nSV = 13, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.160963, rho = 0.528476
# nSV = 26, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.425558, rho = 0.210052
# nSV = 63, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.042543, rho = 0.356983
# nSV = 20, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.628378, rho = 0.868094
# nSV = 61, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.209591, rho = 0.984476
# nSV = 32, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.160562, rho = 1.092543
# nSV = 36, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.090915, rho = 0.797756
# nSV = 28, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.183895, rho = 0.786918
# nSV = 33, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.071981, rho = 0.511408
# nSV = 27, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.301423, rho = 0.695117
# nSV = 51, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.174055, rho = 0.465357
# nSV = 46, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -2.258862, rho = -0.429432
# nSV = 46, nBSV = 2
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.092343, rho = 0.932529
# nSV = 22, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.116269, rho = 0.740382
# nSV = 35, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.075571, rho = 0.712094
# nSV = 21, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.794163, rho = 0.799986
# nSV = 77, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.120902, rho = 0.335158
# nSV = 33, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.168134, rho = 1.676596
# nSV = 40, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.124725, rho = 0.181537
# nSV = 29, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.125904, rho = 1.283429
# nSV = 37, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.123010, rho = 0.674894
# nSV = 26, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.269806, rho = 1.558298
# nSV = 51, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.124037, rho = -0.114028
# nSV = 42, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.211959, rho = 0.159461
# nSV = 40, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.084680, rho = 0.662311
# nSV = 24, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.135450, rho = 1.064887
# nSV = 35, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.131490, rho = -0.516329
# nSV = 24, nBSV = 0
# .*
# optimization finished, #iter = 31
# obj = -0.044376, rho = -0.545146
# nSV = 13, nBSV = 0
# .*.WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.086249, rho = -0.659645
# nSV = 19, nBSV = 0
# .*.*
# optimization finished, #iter = 34
# obj = -0.056412, rho = -0.710571
# nSV = 13, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.189876, rho = 0.286539
# nSV = 25, nBSV = 0
# .*.*
# optimization finished, #iter = 29
# obj = -0.067183, rho = -0.719977
# nSV = 12, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.135551, rho = 0.109031
# nSV = 29, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.040504, rho = -0.189447
# nSV = 23, nBSV = 0
# .*
# optimization finished, #iter = 45
# obj = -0.086780, rho = -1.172674
# nSV = 17, nBSV = 0
# .*.*
# optimization finished, #iter = 26
# obj = -0.050946, rho = -0.265075
# nSV = 10, nBSV = 0
# *.*
# optimization finished, #iter = 39
# obj = -0.074921, rho = 0.836108
# nSV = 18, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.212839, rho = -0.510397
# nSV = 37, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.309523, rho = -0.040972
# nSV = 44, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.148326, rho = -0.338300
# nSV = 32, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.318045, rho = 1.345938
# nSV = 48, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.123896, rho = -0.595682
# nSV = 32, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.705526, rho = 1.718990
# nSV = 69, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.171273, rho = -0.490645
# nSV = 45, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.345098, rho = -1.282518
# nSV = 46, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.137500, rho = 0.430713
# nSV = 31, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.238701, rho = 0.200542
# nSV = 43, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.141785, rho = -0.023073
# nSV = 23, nBSV = 0
# .*.*
# optimization finished, #iter = 43
# obj = -0.074354, rho = -0.025817
# nSV = 17, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.155209, rho = 1.497735
# nSV = 28, nBSV = 0
# .*
# optimization finished, #iter = 31
# obj = -0.055012, rho = -0.339570
# nSV = 14, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.228411, rho = 0.824808
# nSV = 38, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.130099, rho = -0.445782
# nSV = 29, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.181520, rho = -0.846056
# nSV = 26, nBSV = 0
# .*.*
# optimization finished, #iter = 39
# obj = -0.098535, rho = 1.176108
# nSV = 15, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.141328, rho = 0.872838
# nSV = 27, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.128487, rho = -0.047519
# nSV = 23, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.250849, rho = 2.242522
# nSV = 37, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.098159, rho = -1.073608
# nSV = 23, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.415570, rho = 0.563805
# nSV = 53, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.135660, rho = -0.200947
# nSV = 35, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.270187, rho = -1.094649
# nSV = 32, nBSV = 0
# .*.WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.085314, rho = 1.248601
# nSV = 19, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.118990, rho = 0.836242
# nSV = 32, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.128530, rho = 1.268207
# nSV = 25, nBSV = 0
# .*.*
# optimization finished, #iter = 33
# obj = -0.053040, rho = -0.180856
# nSV = 14, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.197151, rho = 0.951710
# nSV = 32, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.074696, rho = -0.194927
# nSV = 27, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.080448, rho = -0.310524
# nSV = 23, nBSV = 0
# .*.*
# optimization finished, #iter = 27
# obj = -0.053745, rho = 0.873094
# nSV = 10, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.076488, rho = 0.945760
# nSV = 25, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.082830, rho = -1.598960
# nSV = 24, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.502504, rho = -1.390152
# nSV = 54, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.099513, rho = -0.453669
# nSV = 36, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.199401, rho = -2.157910
# nSV = 35, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.143411, rho = -0.276244
# nSV = 28, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.231932, rho = -0.819754
# nSV = 39, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.113765, rho = 1.365087
# nSV = 26, nBSV = 0
# *
# optimization finished, #iter = 47
# obj = -0.043727, rho = -0.011762
# nSV = 20, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.102284, rho = 0.262145
# nSV = 21, nBSV = 0
# .*.*
# optimization finished, #iter = 28
# obj = -0.045181, rho = 0.544623
# nSV = 11, nBSV = 0
# .*
# optimization finished, #iter = 49
# obj = -0.049420, rho = 0.929038
# nSV = 19, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.217690, rho = -0.701555
# nSV = 44, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.334307, rho = 0.024552
# nSV = 48, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.151643, rho = 1.035642
# nSV = 30, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.282410, rho = 1.210364
# nSV = 43, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.109085, rho = -0.249420
# nSV = 27, nBSV = 0
# *.WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.087148, rho = 0.234031
# nSV = 23, nBSV = 0
# WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.297068, rho = 2.223783
# nSV = 40, nBSV = 0
# .*.WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.093225, rho = 1.517885
# nSV = 17, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.203629, rho = 1.205856
# nSV = 30, nBSV = 0
# .WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 50
# obj = -0.158396, rho = -0.151973
# nSV = 22, nBSV = 0
# Total nSV = 653
# /home/gpuadmin/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=50).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# SVC(kernel='linear', max_iter=50, verbose=True)

# %%
predList = clf.predict(valFea)

# %%
conf = sklearn.metrics.confusion_matrix(val_labellist, predList, normalize='true')

# %%
plt.imshow(conf)

# %%
per_class_acc = np.diag(conf)
print('mean accuracy: %.3f' % per_class_acc.mean())
# Out:
# mean accuracy: 0.287
